# %% [markdown]
# 26\05\2026

# %% [markdown]
# numpy

# %%
import numpy as np

# %%
# create a array
a=np.array(['python',45,89,12.6,30.27,True])
a

# %%
a1=np.array([45,89,12.6,30.27])
a1

# %%
a1.shape

# %%
a2=np.array([[10,20],[30,40],[4,3]])
a2

# %%
a2.shape

# %%
# to cheak dimention of data
a2.ndim

# %%
len(a2)

# %%
type(a2)

# %%
a2.dtype

# %%
np.zeros((3,3),dtype='int')

# %%
np.ones((2,3),dtype='int')

# %%
np.full((3,3),8)

# %%
np.identity(3,dtype='int')

# %%
np.eye(3,dtype='int')

# %%
# range function
ar1=np.arange(1,10,1)
ar1

# %%
np.reshape(ar1,(3,3))

# %%
# 1 to 20 even num
ar2=np.arange(2,21,2)
ar2

# %%
# 1 to 20 odd num
ar3=np.arange(1,21,2)
ar3

# %%
ar4=np.random.rand(4,5).round(2)
ar4

# %%
ar5=np.random.randint(1,100,(4,5))
ar5
# Out:
# array([[14, 56, 77, 60, 54],
#        [ 3, 82, 39, 74, 42],
#        [59,  5, 64, 53, 26],
#        [47, 91, 76, 70, 52]], dtype=int32)

# %%
np.max(ar5)
# Out:
# np.int32(91)

# %%
ar5.min()

# %%
# create a np array of 3x4 with number from  10 to 50
ar6=np.random.randint(10,50,(3,4))
ar6
# Out:
# array([[40, 13, 37, 17],
#        [41, 21, 28, 31],
#        [22, 49, 37, 31]], dtype=int32)

# %%
np.max(ar6)
# Out:
# np.int32(49)

# %%
np.linspace(10,50,12).round(2)
# Out:
# array([10.  , 13.64, 17.27, 20.91, 24.55, 28.18, 31.82, 35.45, 39.09,
#        42.73, 46.36, 50.  ])

# %%
# analys row wise max value 
row_max=ar6.max(axis=1)
row_max
# Out:
# array([40, 41, 49], dtype=int32)

# %%
# analyse the position of the max value and it is show that 1st-8
np.argmax(arri,axis=1)

# %%
arr1[1,2]

# %%
arr1[0]

# %%
arr1[10]

# %%
arr1

# %%
arr1[2,2] = 44

# %%
arr1[2,2]

# %%
arr1[1,1] = 27

# %%
arr1[1,1:3)

# %%
arr1[::2,1::2]

# %%
arr1.transpose()

# %%
#reverse bath(col, rows)
arr1:-1:-11

# %%
# normalize the value in blw range and 1
#x-min/max-min
new (arr1 arr1.min())/(arr1.max() arri.min())
new

# %%
nем.round(2)

# %%
arr1

# %%
# how to analyse 138 values
arr1[arr1>30]

# %%
# how to analyse 138 values
arr1[arr1>30]

# %%
arr2= np.array(123,-56,39,-18,-12,45,-153) arr2

# %%
arr240
